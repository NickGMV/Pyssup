# %%
# exec('''import urllib; exec(urllib.request.urlopen('https://raw.githubusercontent.com/NickGMV/visual-tools/main/visual-aids-jupyter8.txt').read())''')

# %% [markdown]
# <hr style = "height:5px; background-color: blue; border-color:blue;">
# <hr style = "height:5px; background-color: #89CFF0; border-color:#89CFF0;">
# <hr style = "height:5px; background-color: black; border-color:black;">
#
# ### 10 weeks of Python - Week 2
#
# # Navigating and cleaning data
#
# <hr style = "height:5px; background-color: blue; border-color:blue;">
# <hr style = "height:5px; background-color: #89CFF0; border-color:#89CFF0;">
# <hr style = "height:5px; background-color: black; border-color:black;">

# %% [markdown]
# ### Imports and load data - (see week 1 if stuck)

# %%
# imports
import pandas as pd 
# use numpy nulls
import numpy as np

# %%
#load in data 
countries = pd.read_csv('./data/Country-data.csv')
countries.head()
# Out:
#               couuntry child_mort exports health imports   income  inflation  \
# 0          Afghanistan       90.2      10   7.58    44.9   1610.0       9.44
# 1              Albania       16.6      28   6.55    48.6   9930.0       4.49
# 2              Algeria       27.3    38.4   4.17    31.4  12900.0      16.10
# 3               Angola         ::      ::     ::      ::   5900.0      22.40
# 4  Antigua and Barbuda       10.3    45.5   6.03    58.9  19100.0       1.44
#
#    life_expec total_fer   gdpp
# 0        56.2      5.82    553
# 1        76.3      1.65   4090
# 2        76.5      2.89   4460
# 3        60.1      6.16   3530
# 4        76.8      2.13  12200

# %% [markdown]
# ### Navigating data

# %% [markdown]
# ### Selecting rows and columns
#
#
# There are a plethora of ways to navigate your data we will cover a few here
#
# - dot notation
# - brackets notation
# - loc
# - iloc
# - combined
#
# We looked at selecting columns using dot and bracket notation (refer to week 1)
#
# We will start here by using loc

# %% [markdown]
# ##### Loc

# %%
# loc will find all the rows that have a value in the index (this can be really handy when yur index is not numerical)
countries.loc[0:100]
# Out:
#                 couuntry child_mort exports health imports   income  \
# 0            Afghanistan       90.2      10   7.58    44.9   1610.0
# 1                Albania       16.6      28   6.55    48.6   9930.0
# 2                Algeria       27.3    38.4   4.17    31.4  12900.0
# 3                 Angola         ::      ::     ::      ::   5900.0
# 4    Antigua and Barbuda       10.3    45.5   6.03    58.9  19100.0
# ..                   ...        ...     ...    ...     ...      ...
# 96              Maldives       13.2    77.6   6.33    65.4  10500.0
# 97                  Mali        137    22.8   4.98    35.1   1870.0
# 98                 Malta        6.8     153   8.65     154  28300.0
# 99            Mauritania       97.4    50.7   4.41    61.2   3320.0
# 100            Mauritius         15    51.2      6    62.2  15900.0
#
#      inflation  life_expec total_fer   gdpp
# 0         9.44        56.2      5.82    553
# 1         4.49        76.3      1.65   4090
# ...

# %%
# We wil create a demo of using text indexes
demo_index = countries.set_index('couuntry')

# %%
# we can seach the index quickly with loc
demo_index.loc['Vietnam']
# Out:
#          child_mort exports health imports  income  inflation  life_expec  \
# couuntry
# Vietnam         NaN     NaN    NaN    80.2  4490.0       12.1        73.1
# Vietnam         NaN     NaN    NaN    80.2  4490.0       12.1        73.1
#
#          total_fer  gdpp
# couuntry
# Vietnam       1.95  1310
# Vietnam       1.95  1310

# %%
# You can give lists
demo_index.loc[['Vietnam','Algeria']]
# Out:
#          child_mort exports health imports   income  inflation  life_expec  \
# couuntry
# Vietnam         NaN     NaN    NaN    80.2   4490.0       12.1        73.1
# Vietnam         NaN     NaN    NaN    80.2   4490.0       12.1        73.1
# Algeria        27.3    38.4   4.17    31.4  12900.0       16.1        76.5
#
#          total_fer  gdpp
# couuntry
# Vietnam       1.95  1310
# Vietnam       1.95  1310
# Algeria       2.89  4460

# %%
# Adding a condition we can find all countries beginning with a B

# loc is a little niche notice this line is easier using conventional filters 
demo_index.loc[[x for x in demo_index.index if x[0]=='B']]
# Out:
#                        child_mort exports health imports   income  inflation  \
# couuntry
# Bahamas                      13.8      35   7.89    43.7  22900.0     -0.393
# Bahrain                       8.6    69.5   4.97    50.9  41100.0      7.440
# Bangladesh                   49.4      16   3.52    21.8   2440.0      7.140
# Barbados                     14.2    39.5   7.97    48.7  15300.0      0.321
# Belarus                       5.5    51.4   5.61    64.5  16200.0     15.100
# Belgium                       4.5    76.4   10.7    74.7  41100.0      1.880
# Belize                       18.8    58.2    5.2    57.5   7880.0      1.140
# Benin                         111    23.8    4.1    37.2   1820.0      0.885
# Bhutan                       42.7    42.5    5.2    70.7   6420.0      5.990
# Bolivia                      46.6    41.2   4.84     NaN      NaN        NaN
# Bosnia and Herzegovina        6.9    29.7   11.1    51.3   9720.0      1.400
# ...

# %%
# filter all countries beginning with B
countries[countries['couuntry'].str[0]== 'B']
# Out:
#                   couuntry child_mort exports health imports   income  \
# 10                 Bahamas       13.8      35   7.89    43.7  22900.0
# 11                 Bahrain        8.6    69.5   4.97    50.9  41100.0
# 12              Bangladesh       49.4      16   3.52    21.8   2440.0
# 13                Barbados       14.2    39.5   7.97    48.7  15300.0
# 14                 Belarus        5.5    51.4   5.61    64.5  16200.0
# 15                 Belgium        4.5    76.4   10.7    74.7  41100.0
# 16                  Belize       18.8    58.2    5.2    57.5   7880.0
# 17                   Benin        111    23.8    4.1    37.2   1820.0
# 18                  Bhutan       42.7    42.5    5.2    70.7   6420.0
# 19                 Bolivia       46.6    41.2   4.84     NaN      NaN
# 20  Bosnia and Herzegovina        6.9    29.7   11.1    51.3   9720.0
# 21                Botswana       52.5    43.6    8.3    51.3  13300.0
# ...

# %% [markdown]
# ##### iloc

# %% [markdown]
# ### Iloc
#
# I loc allows us to navigate the data using coordinate systems. It uses a range notation where the range we select is between the numbers either side of the colon e.g 2:4 looks at 2,3 (remember the top index is not included in Python)
#
# Link to documentation here
#
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.iloc.html

# %%
# to pick out data points use iloc
# first set of numbers is from:to for rows
#second set of numbers is from:to for columns

countries.iloc[1:5,0:2]

# pandas uses similar indexing rules to lists in standard python , 
# they start at zero and negative indices work too.


# IMPORTANT in a python range the largest number is NOT included by default (Notice the 5th row isn't shown)
# Out:
#               couuntry child_mort
# 1              Albania       16.6
# 2              Algeria       27.3
# 3               Angola         ::
# 4  Antigua and Barbuda       10.3

# %%
#inputting only one part or other will be interpretted as everything upto or everything from
#this takes every row up to row three and every column from the 5th column (remember 0 indices!)
countries.iloc[:3,4:]
# Out:
#   imports   income  inflation  life_expec total_fer  gdpp
# 0    44.9   1610.0       9.44        56.2      5.82   553
# 1    48.6   9930.0       4.49        76.3      1.65  4090
# 2    31.4  12900.0      16.10        76.5      2.89  4460

# %%
#negative indexing can be useful to collect the last column/ row this comes in handy when processing data for
# machine learning this is because our Y (the value to be predicted) will very often be in the last column.
countries.iloc[-1:,-1:]
# Out:
#      gdpp
# 167  1310

# %% [markdown]
# <hr style = "height:5px; background-color: blue; border-color:blue;">
# <hr style = "height:5px; background-color: #89CFF0; border-color:#89CFF0;">
# <hr style = "height:5px; background-color: black; border-color:black;">
#
# ### Now you try
#  Using your data set from last week (or one of the practice sets)
#
# 1. Use iloc to select the final column
# 2. Create a subset of your data taking only the top 99 rows call it test_set

# %%
# code here

# %% [markdown]
# <hr style = "height:5px; background-color: blue; border-color:blue;">
# <hr style = "height:5px; background-color: #89CFF0; border-color:#89CFF0;">
# <hr style = "height:5px; background-color: black; border-color:black;">
#
# ### Cleaning data

# %% [markdown]
# #### we did EDA in our last session and found some issues to clean
#
# - Duplicates
# - Nulls
# - Spelling mistakes in column names
# - Bad encoding
# - wrong types

# %% [markdown]
# #### Removing duplicates

# %%
# find duplicates 
countries[countries.duplicated()]
# Out:
#     couuntry child_mort exports health imports  income  inflation  life_expec  \
# 167  Vietnam        NaN     NaN    NaN    80.2  4490.0       12.1        73.1
#
#     total_fer  gdpp
# 167      1.95  1310

# %%
# we can remove by a) Making a subset filtering them out
sub = countries[countries.duplicated() != True]

# or b) using the drop_duplicates() function
countries = countries.drop_duplicates()

# %%
# use shape to check that number of rows has changed
countries.shape
# Out:
# (167, 10)

# %% [markdown]
# #### Dealing with nulls

# %%
# find nulls
countries.isna().sum()
# Out:
# couuntry      0
# child_mort    2
# exports       2
# health        2
# imports       2
# income        2
# inflation     2
# life_expec    1
# total_fer     1
# gdpp          0
# dtype: int64

# %%
# deal with them using dropna()
# look in to the options with dropna() to get best results 
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.dropna.html
countries = countries.dropna()
countries.isna().sum()
# Out:
# couuntry      0
# child_mort    0
# exports       0
# health        0
# imports       0
# income        0
# inflation     0
# life_expec    0
# total_fer     0
# gdpp          0
# dtype: int64

# %% [markdown]
# #### Spelling mistakes in column names

# %%
#### get access to columns using .columns
countries.columns
# Out:
# Index(['country', 'child_mort', 'exports', 'health', 'imports', 'income',
#        'inflation', 'life_expec', 'total_fer', 'gdpp'],
#       dtype='object')

# %%
# change columns using rename()
countries = countries.rename(columns = {'couuntry':'country'})
countries.head()
# Out:
#                country child_mort exports health imports   income  inflation  \
# 0          Afghanistan       90.2      10   7.58    44.9   1610.0       9.44
# 1              Albania       16.6      28   6.55    48.6   9930.0       4.49
# 2              Algeria       27.3    38.4   4.17    31.4  12900.0      16.10
# 3               Angola         ::      ::     ::      ::   5900.0      22.40
# 4  Antigua and Barbuda       10.3    45.5   6.03    58.9  19100.0       1.44
#
#    life_expec total_fer   gdpp
# 0        56.2      5.82    553
# 1        76.3      1.65   4090
# 2        76.5      2.89   4460
# 3        60.1      6.16   3530
# 4        76.8      2.13  12200

# %% [markdown]
# #### Bad encoding

# %%
# some nulls are encoded as "::" this disrupts our code from working properly
# use replace() to fix this replace all :: with a null

countries = countries.replace('::', np.nan)
countries.head()
# Out:
#                country child_mort exports health imports   income  inflation  \
# 0          Afghanistan       90.2      10   7.58    44.9   1610.0       9.44
# 1              Albania       16.6      28   6.55    48.6   9930.0       4.49
# 2              Algeria       27.3    38.4   4.17    31.4  12900.0      16.10
# 3               Angola        NaN     NaN    NaN     NaN   5900.0      22.40
# 4  Antigua and Barbuda       10.3    45.5   6.03    58.9  19100.0       1.44
#
#    life_expec total_fer   gdpp
# 0        56.2      5.82    553
# 1        76.3      1.65   4090
# 2        76.5      2.89   4460
# 3        60.1      6.16   3530
# 4        76.8      2.13  12200

# %%
# once the bad encoding is removed we can dropna() etc

# %% [markdown]
# #### Changing data type

# %%
# check our dtypes
countries.dtypes
# Out:
# country        object
# child_mort     object
# exports        object
# health         object
# imports        object
# income        float64
# inflation     float64
# life_expec    float64
# total_fer      object
# gdpp            int64
# dtype: object

# %%
# change columns individually
countries['child_mort'] = countries['child_mort'].astype('float')
countries.dtypes
# Out:
# country        object
# child_mort    float64
# exports        object
# health         object
# imports        object
# income        float64
# inflation     float64
# life_expec    float64
# total_fer      object
# gdpp            int64
# dtype: object

# %%
# change with dictionary
countries = countries.astype({"country":"string",
                  "child_mort":"float64",
                  "exports":"float64",
                  "health":"float64",
                  "imports":"float64",
                  "total_fer":"float64",
                  "gdpp":"float64"
})


countries.dtypes
# Out:
# country        string
# child_mort    float64
# exports       float64
# health        float64
# imports       float64
# income        float64
# inflation     float64
# life_expec    float64
# total_fer     float64
# gdpp          float64
# dtype: object

# %% [markdown]
# <hr style = "height:5px; background-color: blue; border-color:blue;">
# <hr style = "height:5px; background-color: #89CFF0; border-color:#89CFF0;">
# <hr style = "height:5px; background-color: black; border-color:black;">
#
# ### Now you try
#  Using your data set from last week (or one of the practice sets)
#
# Find and address any of the following issues
#
# 1. Duplicates
# 2. Nulls
# 3. Spelling mistakes in column names
# 4. Bad encoding
# 5. wrong types

# %%
# code here

# %% [markdown]
# <hr style = "height:5px; background-color: blue; border-color:blue;">
# <hr style = "height:5px; background-color: #89CFF0; border-color:#89CFF0;">
# <hr style = "height:5px; background-color: black; border-color:black;">
#
#
# ### See you next time
#
#
# <hr style = "height:5px; background-color: blue; border-color:blue;">
# <hr style = "height:5px; background-color: #89CFF0; border-color:#89CFF0;">
# <hr style = "height:5px; background-color: black; border-color:black;">
