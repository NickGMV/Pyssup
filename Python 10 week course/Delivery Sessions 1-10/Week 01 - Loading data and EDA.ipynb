# %%
exec('''import urllib; exec(urllib.request.urlopen('https://raw.githubusercontent.com/NickGMV/visual-tools/main/visual-aids-jupyter8.txt').read())''')
# Out:
# settings found initialising with personal preferences...
# <script>
# var profile = ['134%', '159%', '#af6241', '#ff99d4', '132%', '#37a093', '#282525', '139%']
# </script>
# <script>
# var box1 = document.getElementById('help_box');
# var box2 = document.getElementById('settings');
# var logo = document.getElementById('mvlogo');
# var tt = document.getElementById('tooltip2');
# if(box1){
# //clean out for rebuild
# box1.remove();
# box2.remove();
# logo.remove();
# tt.remove();
# clearInterval(flagEnlarge);
# clearInterval(flagMagnifyOutputs);
# clearInterval(flagHighlightOutput);
# clearInterval(flagHighlight);
# clearInterval(flagHighlightCode);
# clearInterval(flagMagnifyCell);
# clearInterval(flagMagnifyCode);
# }
# else{}
#
#
# var flagHighlight=0;
# var flagHighlightCode = 0;
# var flagMagnifyCell = 0;
# var flagMagnifyCode =0;
# var flagMagnifyOutputs=0;
# var flagEnlarge = 0;
# var flagHighlightOutput = 0;
# var settings_flag = 0;
#
#
# //done markdown enlarge live update
# function enlarge_markdown(){
#
# if(flagEnlarge==0){
# flagEnlarge = setInterval(function(){
# var els = document.getElementsByClassName('text_cell');
# for(let i=0;i<els.length;i++){
# els[i].classList.add('enlarged');}
# },100);
# document.getElementById('button7').classList.toggle('active_button');
# }
# else{
# clearInterval(flagEnlarge)
# flagEnlarge = 0;
# document.getElementById('button7').classList.toggle('active_button');
# var els = document.getElementsByClassName('text_cell');
# for(let i=0;i<els.length;i++){
# els[i].classList.remove('enlarged');
# }};};
#
#
# //done output enlarge live update
#
# function magnify_outputs(){
#
# if(flagMagnifyOutputs==0){
# flagMagnifyOutputs = setInterval(function(){
# var els = document.getElementsByClassName('output_wrapper');
# for(let i=0;i<els.length;i++){
# els[i].classList.add('magnified_output');}
# },100);
# document.getElementById('button5').classList.toggle('active_button');
# }
# else{
# clearInterval(flagMagnifyOutputs)
# flagMagnifyOutputs = 0;
# document.getElementById('button5').classList.toggle('active_button');
# var els = document.getElementsByClassName('output_wrapper');
# for(let i=0;i<els.length;i++){
# els[i].classList.remove('magnified_output');
# }};};
#
# // highlight outputs live update
# // note misnomer here flags and variable names are not descriptive - FIX?
#
#
#
# function magnify_output_lines(){
#
# if(flagHighlightOutput==0){
# flagHighlightOutput = setInterval(function(){
# var els = document.getElementsByClassName('output_wrapper');
# for(let i=0;i<els.length;i++){
# els[i].classList.add('magnified_output_lines');}
# },100);
# document.getElementById('button6').classList.toggle('active_button');
# }
# else{
# clearInterval(flagHighlightOutput)
# flagHighlightOutput = 0;
# document.getElementById('button6').classList.toggle('active_button');
# var els = document.getElementsByClassName('output_wrapper');
# for(let i=0;i<els.length;i++){
# els[i].classList.remove('magnified_output_lines');
# }};};
#
#
#
#
# // Code cells highlight complete working
#
# function highlight_cell(){
#
# if(flagHighlight==0){
# flagHighlight = setInterval(function(){
# var els = document.getElementsByClassName('CodeMirror-lines');
# for(let i=0;i<els.length;i++){
# els[i].classList.add('highlighted');}
# },100);
# document.getElementById('button4').classList.toggle('active_button');
# }
# else{
# clearInterval(flagHighlight)
# flagHighlight = 0;
# document.getElementById('button4').classList.toggle('active_button');
# var els = document.getElementsByClassName('CodeMirror-lines');
# for(let i=0;i<els.length;i++){
# els[i].classList.remove('highlighted');
# }};};
#
#
#
# function highlight_code(){
#
# if(flagHighlightCode==0){
# flagHighlightCode = setInterval(function(){
# var els = document.getElementsByClassName('CodeMirror-lines');
# for(let i=0;i<els.length;i++){
# els[i].classList.add('highlighted_code');}
# },100);
# document.getElementById('button3').classList.toggle('active_button');
# }
# else{
# clearInterval(flagHighlightCode)
# flagHighlightCode = 0;
# document.getElementById('button3').classList.toggle('active_button');
# var els = document.getElementsByClassName('CodeMirror-lines');
# for(let i=0;i<els.length;i++){
# els[i].classList.remove('highlighted_code');
# }};};
#
#
#
# function magnify_cell(){
#
# if(flagMagnifyCell==0){
# flagMagnifyCell = setInterval(function(){
# var els = document.getElementsByClassName('CodeMirror-lines');
# for(let i=0;i<els.length;i++){
# els[i].classList.add('magnified_cell');}
# },100);
# document.getElementById('button2').classList.toggle('active_button');
# }
# else{
# clearInterval(flagMagnifyCell)
# flagMagnifyCell = 0;
# document.getElementById('button2').classList.toggle('active_button');
# var els = document.getElementsByClassName('CodeMirror-lines');
# for(let i=0;i<els.length;i++){
# els[i].classList.remove('magnified_cell');
# }};};
#
#
#
#
#
#
#
#
#
# function magnify_code(){
# if(flagMagnifyCode==0){
# flagMagnifyCode = setInterval(function(){
# var els = document.getElementsByClassName('CodeMirror-lines');
# for(let i=0;i<els.length;i++){
# els[i].classList.add('magnified_code');}
# },100);
# document.getElementById('button1').classList.toggle('active_button');
# }
# else{
# clearInterval(flagMagnifyCode)
# flagMagnifyCode = 0;
# document.getElementById('button1').classList.toggle('active_button');
# var els = document.getElementsByClassName('CodeMirror-lines');
# for(let i=0;i<els.length;i++){
# els[i].classList.remove('magnified_code');
# }};};
#
#
# function toggle_settings(){
#
#
# }
#
# document.getElementsByTagName("BODY")[0].insertAdjacentHTML("afterend", "<div id='help_box'></div>");
# document.getElementsByTagName("BODY")[0].insertAdjacentHTML("afterend","<img src= 'https://github.com/NickGMV/visual-tools/blob/main/eyeicon.png?raw=true' id='mvlogo'>")
# document.getElementsByTagName("BODY")[0].insertAdjacentHTML("afterend", "<div class='hidden' id='tooltip2'><p>click the eye to hide/show tools</p></div>");
# document.getElementsByTagName("BODY")[0].insertAdjacentHTML("afterend","<div id = 'settings' class = 'hidden settings'></div>")
#
# var settings = document.getElementById('settings');
#
# settings.innerHTML +=`
# <div id = 'magnify_settings' class = 'subsettings'>
# <p> Change your magnification level </p>
# <input type="range" min="1" max="99" value="50" class="slider" id="magnify_slider">
# </div>
#
# <div id = 'magnify_cell' class = 'subsettings'>
# <p> Change your enlargement level </p>
# <input type="range" min="1" max="99" value="50" class="slider" id="cell_slider"></div>
#
# <div id = 'highlight_line_settings' class = 'subsettings'>
# <p> Change your line highlight colour </p>
# <input type="color" id="colorpicker1" value="#0000ff">
# </div>
#
# <div id = 'highlight_settings' class = 'subsettings'>
# <p> Change your code cell highlight colour </p>
# <input type="color" id="colorpicker2" value="#0000ff">
# </div>
#
# <div id = 'output_enlarge_settings' class = 'subsettings'>
# <p> Change your magnification level </p>
# <input type="range" min="1" max="100" value="50" class="slider" id="output_mag_slider">
# </div>
#
# <div id = 'output_highlight_settings' class = 'subsettings'>
# <p> Change your output highlighting </p>
# <input type="color" id="colorpicker3" value="#0000ff">
# </div>
#
# <div id = 'output_highlight_settings' class = 'subsettings'>
# <p> Change your output font-color </p>
# <input type="color" id="colorpicker4" value="#0000ff">
# </div>
#
# <div id = 'Markdown_enlarge_settings' class = 'subsettings'>
# <p> Change your Mark down magnification </p>
# <input type="range" min="1" max="99" value="50" class="slider" id="markdown_slider">
# </div>
#
# <div id= "save_load_settings" class = "buttons">
# <!--<button id= "save_settings">save my preferences</button><button id="load">load my preferences</button>-->
# Save your settings
# </div>
# `
# //settings functions
#
# //for code cells
#
# // make magnify line settings work
# document.getElementById('magnify_slider').addEventListener('change',function(){
# var slider = document.getElementById('magnify_slider');
# //window.alert(100 + parseInt(slider.value) +'%')
# var r = document.querySelector(':root');
# //var rs = getComputedStyle(r);
# r.style.setProperty('--magnify-zoom', 100 + parseInt(slider.value) +'%' );
# })
#
# // make magnify code cells settings work
# document.getElementById('cell_slider').addEventListener('change',function(){
# var slider = document.getElementById

# %% [markdown]
# <hr style = "height:5px; background-color: blue; border-color:blue;">
# <hr style = "height:5px; background-color: #89CFF0; border-color:#89CFF0;">
# <hr style = "height:5px; background-color: black; border-color:black;">
#
# ### 10 weeks of Python - Week 1
#
# # Loading data and EDA
#
# <hr style = "height:5px; background-color: blue; border-color:blue;">
# <hr style = "height:5px; background-color: #89CFF0; border-color:#89CFF0;">
# <hr style = "height:5px; background-color: black; border-color:black;">

# %% [markdown]
# ### Imports

# %%
# always Start with imports
import pandas as pd

# %% [markdown]
# ### Loading data and paths
#
# We will load our data using read_csv in pandas, to load your data you will need to know its path a path is effectively the directions to your data, python can iether start at your python file and navigate fom there (relative), Or start at the root of your harddrive and navigate from there (absolute), Python can also navigate and find data online.

# %%
# To load in data use read_csv
my_first_df = pd.read_csv('../Assets/Data/Country-data.csv')

#check the data ising head to peek at first 5 rows
my_first_df.head()
# Out:
#               couuntry child_mort exports health imports   income  inflation  \
# 0          Afghanistan       90.2      10   7.58    44.9   1610.0       9.44
# 1              Albania       16.6      28   6.55    48.6   9930.0       4.49
# 2              Algeria       27.3    38.4   4.17    31.4  12900.0      16.10
# 3               Angola         ::      ::     ::      ::   5900.0      22.40
# 4  Antigua and Barbuda       10.3    45.5   6.03    58.9  19100.0       1.44
#
#    life_expec total_fer   gdpp
# 0        56.2      5.82    553
# 1        76.3      1.65   4090
# 2        76.5      2.89   4460
# 3        60.1      6.16   3530
# 4        76.8      2.13  12200

# %% [markdown]
# #### Now to play with paths
#
# In any project we want us and our stakeholders to be able to access our data quickly and easily, sometimes and absolute path is best, other times a relative one.

# %%
# This is a relative path, it is the trail from our python file to the data file

df_relative_path = pd.read_csv('../Assets/Data/Country-data.csv')
df_relative_path.head()

# To get the relative path work out the path you need to take to get to your data

# relative paths are good when sharing python and data in a folder (like this session)
# Out:
#               couuntry child_mort exports health imports   income  inflation  \
# 0          Afghanistan       90.2      10   7.58    44.9   1610.0       9.44
# 1              Albania       16.6      28   6.55    48.6   9930.0       4.49
# 2              Algeria       27.3    38.4   4.17    31.4  12900.0      16.10
# 3               Angola         ::      ::     ::      ::   5900.0      22.40
# 4  Antigua and Barbuda       10.3    45.5   6.03    58.9  19100.0       1.44
#
#    life_expec total_fer   gdpp
# 0        56.2      5.82    553
# 1        76.3      1.65   4090
# 2        76.5      2.89   4460
# 3        60.1      6.16   3530
# 4        76.8      2.13  12200

# %%
# This is an abolute path, it uses the address of the data on the hardrive

df_absolute_path = pd.read_csv(r"C:\Users\Nick\Desktop\Python 10 week course\Assets\Data\Country-data.csv")
df_absolute_path.head()

# To get an aboslute path access the porperties on your data file and copy its path, OR
# Right click on your data file and select "copy as path" then you can paste in the address directly

# If you have an absolute path yuo must add an r before the string to make it "raw" or it won't work

# Absolute paths are best for their speed to set up (if file structures are convoluted) 
# and for using them to pull data directly from files online
# Out:
#               couuntry child_mort exports health imports   income  inflation  \
# 0          Afghanistan       90.2      10   7.58    44.9   1610.0       9.44
# 1              Albania       16.6      28   6.55    48.6   9930.0       4.49
# 2              Algeria       27.3    38.4   4.17    31.4  12900.0      16.10
# 3               Angola         ::      ::     ::      ::   5900.0      22.40
# 4  Antigua and Barbuda       10.3    45.5   6.03    58.9  19100.0       1.44
#
#    life_expec total_fer   gdpp
# 0        56.2      5.82    553
# 1        76.3      1.65   4090
# 2        76.5      2.89   4460
# 3        60.1      6.16   3530
# 4        76.8      2.13  12200

# %%
# In the case of our workshop, I want to share this efficiently and within a file structure(folder) 
# that won't change so relative path makes the most sense

countries = pd.read_csv('../Assets/Data/Country-data.csv')
countries.head()
# Out:
#               couuntry child_mort exports health imports   income  inflation  \
# 0          Afghanistan       90.2      10   7.58    44.9   1610.0       9.44
# 1              Albania       16.6      28   6.55    48.6   9930.0       4.49
# 2              Algeria       27.3    38.4   4.17    31.4  12900.0      16.10
# 3               Angola         ::      ::     ::      ::   5900.0      22.40
# 4  Antigua and Barbuda       10.3    45.5   6.03    58.9  19100.0       1.44
#
#    life_expec total_fer   gdpp
# 0        56.2      5.82    553
# 1        76.3      1.65   4090
# 2        76.5      2.89   4460
# 3        60.1      6.16   3530
# 4        76.8      2.13  12200

# %% [markdown]
# <hr style = "height:5px; background-color: blue; border-color:blue;">
# <hr style = "height:5px; background-color: #89CFF0; border-color:#89CFF0;">
# <hr style = "height:5px; background-color: black; border-color:black;">
#
# ### Now you try
#
# 1) Load in your dataset (or a practice set from the data folder) experiment with using relative or absolute paths
#
# 2) Consider the following which path method would be best for these situations (R/A)
#
# - A collaborative project shared with multiple people
# - A quick check on some data on your machine
# - A report/code in jupyter you want to send to your boss
# - Accessing a datasource hosted online

# %%
# code here

practice_data = pd.read_csv(r"C:\Users\Nick\Desktop\Python 10 week course\Assets\Data\insurance.csv")

practice_data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# <hr style = "height:5px; background-color: blue; border-color:blue;">
# <hr style = "height:5px; background-color: #89CFF0; border-color:#89CFF0;">
# <hr style = "height:5px; background-color: black; border-color:black;">
#
# ### EDA(exploratory data analysis)
#
# EDA is a quick surface level exploration of your data, we will lok at some of the functions you can use to do this.

# %% [markdown]
# #### Basic EDA - summaries

# %%
# Show us the data tyes we have
countries.dtypes
# Out:
# couuntry       object
# child_mort     object
# exports        object
# health         object
# imports        object
# income        float64
# inflation     float64
# life_expec    float64
# total_fer      object
# gdpp            int64
# dtype: object

# %%
# bring up info on our dataset nulls etc
countries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168 entries, 0 to 167
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   couuntry    168 non-null    object
#  1   child_mort  165 non-null    object
#  2   exports     165 non-null    object
#  3   health      165 non-null    object
#  4   imports     166 non-null    object
#  5   income      166 non-null    float64
#  6   inflation   166 non-null    float64
#  7   life_expec  167 non-null    float64
#  8   total_fer   167 non-null    object
#  9   gdpp        168 non-null    int64
# dtypes: float64(3), int64(1), object(6)
# memory usage: 13.2+ KB

# %%
# describe will give us a set of summary stats on our data
countries.describe()
# Out:
#               income   inflation  life_expec           gdpp
# count     166.000000  166.000000  167.000000     168.000000
# mean    17232.427711    7.822807   70.601198   12894.785714
# std     19302.107152   10.604188    8.886588   18295.853169
# min       609.000000   -4.210000   32.100000     231.000000
# 25%      3457.500000    1.790000   65.300000    1310.000000
# 50%     10180.000000    5.415000   73.100000    4635.000000
# 75%     22850.000000   11.050000   76.800000   13775.000000
# max    125000.000000  104.000000   82.800000  105000.000000

# %%
# get a null count

# checks every item gives true if null false if it has a value
# Not super useful on it's own but combined with a sum function it's very handy
pd.isna(countries).head(5)
# Out:
#    couuntry  child_mort  exports  health  imports  income  inflation  \
# 0     False       False    False   False    False   False      False
# 1     False       False    False   False    False   False      False
# 2     False       False    False   False    False   False      False
# 3     False       False    False   False    False   False      False
# 4     False       False    False   False    False   False      False
#
#    life_expec  total_fer   gdpp
# 0       False      False  False
# 1       False      False  False
# 2       False      False  False
# 3       False      False  False
# 4       False      False  False

# %%
# get a column by column sumary of nulls
countries.isna().sum()
# Out:
# couuntry      0
# child_mort    3
# exports       3
# health        3
# imports       2
# income        2
# inflation     2
# life_expec    1
# total_fer     1
# gdpp          0
# dtype: int64

# %%
# Get a whole data base null count
countries.isna().sum().sum()
# Out:
# 17

# %%
# finds any duplicated rows
countries.duplicated().sum()
# Out:
# 1

# %%
countries = countries.drop_duplicates()
countries.duplicated().sum()
# Out:
# 0

# %% [markdown]
# <hr style = "height:5px; background-color: blue; border-color:blue;">
# <hr style = "height:5px; background-color: #89CFF0; border-color:#89CFF0;">
# <hr style = "height:5px; background-color: black; border-color:black;">
#
# ### Now you try
#
# Try finding these summary stats etc on your dataset (or use the pratice dataset)

# %%
# code here

practice_data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
# controversial 
practice_data.isna().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
# controversial
pd.isna(practice_data).sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
practice_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1339 entries, 0 to 1338
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1339 non-null   int64
#  1   sex       1339 non-null   object
#  2   bmi       1339 non-null   float64
#  3   children  1339 non-null   int64
#  4   smoker    1339 non-null   object
#  5   region    1339 non-null   object
#  6   charges   1339 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.4+ KB

# %%
practice_data.describe(percentiles = [])
# Out:
#                age          bmi     children       charges
# count  1339.000000  1339.000000  1339.000000   1339.000000
# mean     39.194175    30.661445     1.094100  13262.121488
# std      14.052579     6.096326     1.205414  12109.295086
# min      18.000000    15.960000     0.000000   1121.873900
# 50%      39.000000    30.400000     1.000000   9377.904700
# max      64.000000    53.130000     5.000000  63770.428010

# %% [markdown]
# <hr style = "height:5px; background-color: blue; border-color:blue;">
# <hr style = "height:5px; background-color: #89CFF0; border-color:#89CFF0;">
# <hr style = "height:5px; background-color: black; border-color:black;">
#
# #### More EDA - filtering and simple aggregates

# %% [markdown]
# ##### Basic aggregates

# %%
countries.head()
# Out:
#               couuntry child_mort exports health imports   income  inflation  \
# 0          Afghanistan       90.2      10   7.58    44.9   1610.0       9.44
# 1              Albania       16.6      28   6.55    48.6   9930.0       4.49
# 2              Algeria       27.3    38.4   4.17    31.4  12900.0      16.10
# 3               Angola         ::      ::     ::      ::   5900.0      22.40
# 4  Antigua and Barbuda       10.3    45.5   6.03    58.9  19100.0       1.44
#
#    life_expec total_fer   gdpp
# 0        56.2      5.82    553
# 1        76.3      1.65   4090
# 2        76.5      2.89   4460
# 3        60.1      6.16   3530
# 4        76.8      2.13  12200

# %%
# Aggregates can be found by using their function
# If a field is non-numeric or has any strings in it mean will skip
# looks like we have some issues here!
countries[['life_expec','income']].std()
# Out:
# life_expec        8.886588
# income        19302.107152
# dtype: float64

# %%
# alternatively select a column before/after taking the mean
countries['income'].mean()
#or
countries.mean()['income']
# Out:
# 17232.427710843374

# %%
# selecting a column can be done two ways 

# dot notation
countries.exports
# Out:
# 0        10
# 1        28
# 2      38.4
# 3        ::
# 4      45.5
#        ...
# 163    28.5
# 164     NaN
# 165      30
# 166      37
# 167     NaN
# Name: exports, Length: 168, dtype: object

# %%
# or bracket notation
countries['exports']
# Out:
# 0        10
# 1        28
# 2      38.4
# 3        ::
# 4      45.5
#        ...
# 163    28.5
# 164     NaN
# 165      30
# 166      37
# 167     NaN
# Name: exports, Length: 168, dtype: object

# %%
# bracket notation is more robust and arguably more readable, 
# dot notation breaks when space or special characters are used 

# It's worth knowing both

# %%
# A good function to know though not strictly an aggregate is value_counts() which counts
# how many times a value comes up in a given column
countries['exports'].value_counts()
# Out:
# 35      3
# 14.9    2
# 50.2    2
# 26.9    2
# 22.8    2
#        ..
# 53.4    1
# 24.4    1
# 32.2    1
# 65.3    1
# 32.6    1
# Name: exports, Length: 148, dtype: int64

# %% [markdown]
# ##### Filters

# %%
# To filter put a logic condition square brackets

# find all countries withincomes under 1500
countries[countries['income']<1500]
# Out:
#                      couuntry child_mort exports health imports  income  \
# 25               Burkina Faso        116    19.2   6.74    29.6  1430.0
# 26                    Burundi       93.6    8.92   11.6    39.2   764.0
# 31   Central African Republic        149    11.8   3.98    26.5   888.0
# 36                    Comoros       88.2    16.5   4.51    51.7  1410.0
# 37           Congo, Dem. Rep.        116    41.1   7.91    49.6   609.0
# 50                    Eritrea       55.2    4.79   2.66    23.3  1420.0
# 63                     Guinea        109    30.3   4.93    43.2  1190.0
# 64              Guinea-Bissau        114    14.9    8.5    35.2  1390.0
# 88                    Liberia       89.3    19.1   11.8    92.6   700.0
# 93                 Madagascar       62.2      25   3.77      43  1390.0
# 94                     Malawi       90.5    22.8   6.59    34.9  1030.0
# 106                Mozambique        101    31.5   5.21    46.2   918.0
# 112                     Niger        123    22.2   5.16    49.1   814.0
# 126                    Rwanda       63.6      12   10.5      30  1350.0
# 132              Sierra Leone        160    16.8   13.1    34.5  1220.0
# 150                      Togo       90.3    40.2   7.65    57.3  1210.0
#
#      inflation  life_expec total_fer  gdpp
# 25        6.81        57.9      5.87   575
# 26       12.30        57.7      6.26   231
# 31        2.01        47.5      5.21   446
# 36        3.87        65.9      4.75   769
# 37       20.80        57.5      6.54   334
# 50       11.60        61.7      4.61   482
# 63       16.10        58.0      5.34   648
# 64        2.97        55.6      5.05   547
# 88        5.47        60.8      5.02   327
# 93        8.79        60.8       4.6   413
# 94       12.10        53.1      5.31   459
# 106       7.64        54.5      5.56   419
# 112       2.55        58.8      7.49   348
# 126       2.61        64.6      4.51   563
# 132      17.20        55.0       5.2   399
# 150       1.18        58.7      4.87   488

# %%
# to combine use (& / |) to mean (and / or) and wrap each logic condition in round brackets

# find all countries with income under 1500 and GDP over 500
countries[(countries['income']<1500) & (countries['gdpp']>500) ]
# Out:
#           couuntry child_mort exports health imports  income  inflation  \
# 25    Burkina Faso        116    19.2   6.74    29.6  1430.0       6.81
# 36         Comoros       88.2    16.5   4.51    51.7  1410.0       3.87
# 63          Guinea        109    30.3   4.93    43.2  1190.0      16.10
# 64   Guinea-Bissau        114    14.9    8.5    35.2  1390.0       2.97
# 126         Rwanda       63.6      12   10.5      30  1350.0       2.61
#
#      life_expec total_fer  gdpp
# 25         57.9      5.87   575
# 36         65.9      4.75   769
# 63         58.0      5.34   648
# 64         55.6      5.05   547
# 126        64.6      4.51   563

# %%
# You can save your conditions for later using using a variable (often reffered to as a mask)
mask = (countries['income']<1500) & (countries['gdpp']>500)

new_subset = countries[mask]
new_subset
# Out:
#           couuntry child_mort exports health imports  income  inflation  \
# 25    Burkina Faso        116    19.2   6.74    29.6  1430.0       6.81
# 36         Comoros       88.2    16.5   4.51    51.7  1410.0       3.87
# 63          Guinea        109    30.3   4.93    43.2  1190.0      16.10
# 64   Guinea-Bissau        114    14.9    8.5    35.2  1390.0       2.97
# 126         Rwanda       63.6      12   10.5      30  1350.0       2.61
#
#      life_expec total_fer  gdpp
# 25         57.9      5.87   575
# 36         65.9      4.75   769
# 63         58.0      5.34   648
# 64         55.6      5.05   547
# 126        64.6      4.51   563

# %% [markdown]
# <hr style = "height:5px; background-color: blue; border-color:blue;">
# <hr style = "height:5px; background-color: #89CFF0; border-color:#89CFF0;">
# <hr style = "height:5px; background-color: black; border-color:black;">
#
# ### Now you try
#
# Try finding aggregates and filtering on your dataset (or use the pratice dataset)

# %%
#code here

# %% [markdown]
# <hr style = "height:5px; background-color: blue; border-color:blue;">
# <hr style = "height:5px; background-color: #89CFF0; border-color:#89CFF0;">
# <hr style = "height:5px; background-color: black; border-color:black;">
#
#
# ### See you next time
#
#
# <hr style = "height:5px; background-color: blue; border-color:blue;">
# <hr style = "height:5px; background-color: #89CFF0; border-color:#89CFF0;">
# <hr style = "height:5px; background-color: black; border-color:black;">
